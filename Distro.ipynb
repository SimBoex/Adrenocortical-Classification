# %%
import matplotlib.pyplot as plt
def StackedHist(df):
    # Aggregate counts by Center and Morf_Codificata
    counts = df.groupby(['luogoTC_codificato', 'morf_codificata']).size().unstack(fill_value=0)

    # Define all possible center labels (1 to 14)
    all_centers = list(range(1, 15))
    all_labels = sorted(set(map(int,df['morf_codificata'])))
    
    # Reindex the DataFrame to include all centers, filling missing values with 0
    counts = counts.reindex(index=all_centers, columns=all_labels, fill_value=0)

    # Create the stacked histogram
    fig, ax = plt.subplots(figsize=(12, 10))

    # Initialize bottom positions for stacking
    bottom = np.zeros(len(all_centers))
    
    
    colors = plt.cm.tab20.colors



    # Plot each Morf_Codificata category as a stacked bar segment
    for i, label in enumerate(all_labels):
        ax.bar(all_centers, counts[label], bottom=bottom, label=f'{label}', color=colors[i])
        bottom += counts[label].values  # Update bottom for next stack

    # Set x-ticks from 1 to 14
    ax.set_xticks(all_centers)
    ax.set_xticklabels(all_centers, rotation=45, ha='right')

    # Adding labels and title
    plt.xlabel('Center')
    plt.ylabel('Count')
    plt.title('Stacked Histogram by Center and Morf_Codificata')
    plt.legend(title='Morf_Codificata', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("Dataset/Cleaned_dataset.xlsx")
df.shape
# Out:
# (1046, 128)

# %%
StackedHist(df)

# %%
# Count each category
center1 = df[df["luogoTC_codificato"] == 1]
category_counts = center1['morf_codificata'].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    281
# 1    122
# 4     48
# 3     45
# 2     22
# 5     19
# Name: count, dtype: int64

# %%
center2 = df[df["luogoTC_codificato"] == 2]
# Count each category
category_counts = center2["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    14
# 1     4
# Name: count, dtype: int64

# %%
center3 = df[df["luogoTC_codificato"] == 3]
# Count each category
category_counts = center3["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    61
# 1    11
# 2     1
# Name: count, dtype: int64

# %%
center4 = df[df["luogoTC_codificato"] == 4]
# Count each category
category_counts = center4["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    39
# 1     4
# Name: count, dtype: int64

# %%
center5 = df[df["luogoTC_codificato"] == 5]
# Count each category
category_counts = center5["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    47
# 1    14
# Name: count, dtype: int64

# %%
center6 = df[df["luogoTC_codificato"] == 6]
# Count each category
category_counts = center6["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    19
# 1    17
# 2     8
# Name: count, dtype: int64

# %%
center7 = df[df["luogoTC_codificato"] == 7]
# Count each category
category_counts = center7["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 2    9
# Name: count, dtype: int64

# %%
center8 = df[df["luogoTC_codificato"] == 8]
# Count each category
category_counts = center8["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    18
# 1     3
# Name: count, dtype: int64

# %%
center9 = df[df["luogoTC_codificato"] == 9]
# Count each category
category_counts = center9["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    34
# 1    14
# Name: count, dtype: int64

# %%
center10 = df[df["luogoTC_codificato"] == 10]
# Count each category
category_counts = center10["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    3
# 2    2
# 1    2
# Name: count, dtype: int64

# %%
center11 = df[df["luogoTC_codificato"] == 11]
# Count each category
category_counts = center11["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 2    38
# 0    25
# 3    15
# 1    11
# Name: count, dtype: int64

# %%
center12 = df[df["luogoTC_codificato"] == 12]
# Count each category
category_counts = center12["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    32
# 1    15
# 2     4
# 4     1
# Name: count, dtype: int64

# %%
center13 = df[df["luogoTC_codificato"] == 13]
# Count each category
category_counts = center13["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 0    17
# 1    11
# 2     4
# Name: count, dtype: int64

# %%
center14 = df[df["luogoTC_codificato"] == 14]
# Count each category
category_counts = center14["morf_codificata"].value_counts()
print(category_counts)
# Out:
# morf_codificata
# 2    12
# Name: count, dtype: int64
