# %%
''' 
SMOTE LOG REG BINARY
'''
from sklearn.metrics import  accuracy_score, confusion_matrix,precision_score, recall_score, f1_score,roc_auc_score,roc_curve,precision_recall_curve, average_precision_score
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV,RepeatedStratifiedKFold
from   Models import SMOTE_LogReg
from sklearn.model_selection import StratifiedKFold

'''
This return  the features found during the training
'''
import pandas as pd
def FoundFeatures(Path):
    # reading the found dataset for the training
    df = pd.read_excel(Path)
    Features = set(df.columns)
    return Features

# removing the id and the subtypes of a given dataset
def extract_PATIENT_INFO(db):
    ids =  db.pop("ID")
    morf_codificata = db.pop("morf_codificata")
    luogoTC = db.pop("luogoTC_codificato")
    return db, ids, morf_codificata, luogoTC

# %%
db = pd.read_excel("Dataset/Cleaned_dataset.xlsx")

 # extrating the label
y = db.pop("maligno")
X = db

# configure the cross-validation procedure
cv_outer = StratifiedKFold(n_splits=5,shuffle=True, random_state=42)
# enumerate splits
outer_results = list()
best_params_per_fold = []
scores = pd.DataFrame(columns=['Outer Fold',"Grid-Search",'F1-score', 'Recall', 'Precision', 'Accuracy', 'Auc-Score', '#Features'])

for index, (train_ix, test_ix) in enumerate(cv_outer.split(X, y)):
    # split data
    X_train, X_test = X.iloc[train_ix, :], X.iloc[test_ix, :]
    y_train, y_test = y.iloc[train_ix], y.iloc[test_ix]
    # configure the cross-validation procedure
    cv_inner = StratifiedKFold(n_splits=5,shuffle = True, random_state=42)
    pipeline = SMOTE_LogReg.Define_Pipeline()

    X_train, ids, morf_codificata,luogoTC = extract_PATIENT_INFO(X_train)
    Grid_searchOBJ = SMOTE_LogReg.Grid_Search(pipeline=pipeline,cv=cv_inner, X_train=X_train, y_train=y_train)

    best_params = Grid_searchOBJ.best_params_
    best_params_per_fold.append(Grid_searchOBJ.best_params_)
    print(f"Fold {len(best_params_per_fold)}: Best Params = {Grid_searchOBJ.best_params_}")

    ##### Elements/Multi_SMOTE_LogReg/AcrossSplits
    Grid_searchOBJ = SMOTE_LogReg.Grid_Search(pipeline=pipeline,cv = cv_inner, X_train=X_train, y_train=y_train)
    Chosen_pipeline = SMOTE_LogReg.Define_Pipeline()
    Chosen_pipeline.set_params(**Grid_searchOBJ.best_params_)
    fitted_pipeline = SMOTE_LogReg.fit(pipeline=Chosen_pipeline, X_train=X_train, y_train=y_train, Prefix="AcrossSplits/Split{}_".format(index))
    X_test, ids_test, morf_codificata_test,luogoTC = extract_PATIENT_INFO(X_test)
    
    predictions = fitted_pipeline.predict(X_test)
    probs = fitted_pipeline.predict_proba(X_test)
    
    ###Metrics
    Accuracy = round(accuracy_score(y_test, predictions),3)
    precision = round(precision_score(y_test, predictions),3)
    recall = round(recall_score(y_test, predictions),3)
    f1 = round(f1_score(y_test, predictions),3)
    probs = probs[:, 1]
    auc_roc = round(roc_auc_score(y_test,probs),3)
    print("TEST TIME F1 is ", f1)
	##Features
    AllFeaturesSMOTE_LogReg = FoundFeatures("./Elements/SMOTE_LogReg/AcrossSplits/Split{}_SMOTE_LogReg_ReduceDataset.xlsx".format(index))
    print("it has found {} features".format(len(AllFeaturesSMOTE_LogReg)))

    new_row = [index, Grid_searchOBJ.best_score_, f1, recall, precision, Accuracy, auc_roc, len(AllFeaturesSMOTE_LogReg)]  
    scores.loc[index] = new_row  # Append the new row
    
scores["Outer Fold"] = scores["Outer Fold"].astype(int)
scores["#Features"] = scores["#Features"].astype(int)
scores.to_csv('Elements/SMOTE_LogReg/AcrossSplits/scores.csv', index=False)  # index=False to avoid saving the row numbers
scores
# Out:
# [2024-11-08 17:52:41,744: INFO: SMOTE_LogReg: Defining the pipeline...]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.784481 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fold 1: Best Params = {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.784481 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# [2024-11-08 17:52:50,922: INFO: SMOTE_LogReg: Defining the pipeline...]
# Time taken to fit the model: 0.06882 seconds
# [2024-11-08 17:52:52,203: INFO: SMOTE_LogReg: saving the resulting dataframe into: SMOTE_LogReg_ReduceDataset.xlsx]
# TEST TIME F1 is  0.753
# it has found 124 features
# [2024-11-08 17:52:52,856: INFO: SMOTE_LogReg: Defining the pipeline...]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.787157 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fold 2: Best Params = {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.787157 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# [2024-11-08 17:53:00,649: INFO: SMOTE_LogReg: Defining the pipeline...]
# Time taken to fit the model: 0.0699 seconds
# [2024-11-08 17:53:01,887: INFO: SMOTE_LogReg: saving the resulting dataframe into: SMOTE_LogReg_ReduceDataset.xlsx]
# TEST TIME F1 is  0.771
# it has found 124 features
# [2024-11-08 17:53:02,619: INFO: SMOTE_LogReg: Defining the pipeline...]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.772749 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 5, 'smote__sampling_strategy': 'auto'}
# Fold 3: Best Params = {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 5, 'smote__sampling_strategy': 'auto'}
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.772749 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 5, 'smote__sampling_strategy': 'auto'}
# [2024-11-08 17:53:10,790: INFO: SMOTE_LogReg: Defining the pipeline...]
# Time taken to fit the model: 0.06536 seconds
# [2024-11-08 17:53:12,051: INFO: SMOTE_LogReg: saving the resulting dataframe into: SMOTE_LogReg_ReduceDataset.xlsx]
# TEST TIME F1 is  0.774
# it has found 124 features
# [2024-11-08 17:53:12,711: INFO: SMOTE_LogReg: Defining the pipeline...]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.787132 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fold 4: Best Params = {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.787132 using {'logistic_regression__C': 0.1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'newton-cg', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# [2024-11-08 17:53:20,998: INFO: SMOTE_LogReg: Defining the pipeline...]
# Time taken to fit the model: 0.05397 seconds
# [2024-11-08 17:53:22,271: INFO: SMOTE_LogReg: saving the resulting dataframe into: SMOTE_LogReg_ReduceDataset.xlsx]
# TEST TIME F1 is  0.75
# it has found 124 features
# [2024-11-08 17:53:22,940: INFO: SMOTE_LogReg: Defining the pipeline...]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.763830 using {'logistic_regression__C': 1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'liblinear', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fold 5: Best Params = {'logistic_regression__C': 1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'liblinear', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: 0.763830 using {'logistic_regression__C': 1, 'logistic_regression__max_iter': 300, 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'liblinear', 'smote__k_neighbors': 8, 'smote__sampling_strategy': 'auto'}
# [2024-11-08 17:53:31,280: INFO: SMOTE_LogReg: Defining the pipeline...]
# Time taken to fit the model: 0.07015 seconds
# [2024-11-08 17:53:32,526: INFO: SMOTE_LogReg: saving the resulting dataframe into: SMOTE_LogReg_ReduceDataset.xlsx]
# TEST TIME F1 is  0.792
# it has found 124 features
#    Outer Fold  Grid-Search  F1-score  Recall  Precision  Accuracy  Auc-Score  \
# 0           0     0.784481     0.753   0.833      0.686     0.890      0.948
# 1           1     0.787157     0.771   0.902      0.673     0.895      0.969
# 2           2     0.772749     0.774   0.857      0.706     0.900      0.966
# 3           3     0.787132     0.750   0.857      0.667     0.885      0.952
# 4           4     0.763830     0.792   0.905      0.704     0.904      0.954
#
#    #Features
# 0        124
# 1        124
# 2        124
# 3        124
# 4        124

# %%
best_params_per_fold
# Out:
# [{'logistic_regression__C': 0.1,
#   'logistic_regression__max_iter': 300,
#   'logistic_regression__penalty': 'l2',
#   'logistic_regression__solver': 'newton-cg',
#   'smote__k_neighbors': 8,
#   'smote__sampling_strategy': 'auto'},
#  {'logistic_regression__C': 0.1,
#   'logistic_regression__max_iter': 300,
#   'logistic_regression__penalty': 'l2',
#   'logistic_regression__solver': 'lbfgs',
#   'smote__k_neighbors': 8,
#   'smote__sampling_strategy': 'auto'},
#  {'logistic_regression__C': 0.1,
#   'logistic_regression__max_iter': 300,
#   'logistic_regression__penalty': 'l2',
#   'logistic_regression__solver': 'newton-cg',
#   'smote__k_neighbors': 5,
#   'smote__sampling_strategy': 'auto'},
#  {'logistic_regression__C': 0.1,
#   'logistic_regression__max_iter': 300,
#   'logistic_regression__penalty': 'l2',
#   'logistic_regression__solver': 'newton-cg',
#   'smote__k_neighbors': 8,
#   'smote__sampling_strategy': 'auto'},
#  {'logistic_regression__C': 1,
#   'logistic_regression__max_iter': 300,
#   'logistic_regression__penalty': 'l2',
#   'logistic_regression__solver': 'liblinear',
#   'smote__k_neighbors': 8,
#   'smote__sampling_strategy': 'auto'}]

# %%
import numpy as np
def compute_stats(scores):
    cols = scores.columns[1:-1]
    mean_row_values = scores[cols].mean()
    std_row_values = scores[cols].std()
    
    # Create new rows with NaNs for the columns that will be replaced
    mean_row = pd.Series("", index=scores.columns, name='mean')
    std_row = pd.Series("", index=scores.columns, name='std')
    mean_row[cols] = mean_row_values.round(3)
    std_row[cols] = std_row_values.round(3)
    
    # Convert Series to DataFrame
    mean_df = mean_row.to_frame().T
    std_df = std_row.to_frame().T
    
    scores_new = pd.concat([scores, mean_df, std_df], axis = 0)
    
    scores_new.loc["mean","#Features"] = str(int(round(np.mean(scores_new["#Features"][:-2]),0)))
    scores_new.loc["std","#Features"] = str(int(round(np.std( scores_new["#Features"][:-2]),0)))
    
    scores_new.to_csv('Elements/SMOTE_LogReg/AcrossSplits/scores.csv', index=False)  # index=False to avoid saving the row numbers
    
    return scores_new

scores_agg = compute_stats(scores)
scores_agg
# Out:
#      Outer Fold Grid-Search F1-score Recall Precision Accuracy Auc-Score  \
# 0             0    0.784481    0.753  0.833     0.686     0.89     0.948
# 1             1    0.787157    0.771  0.902     0.673    0.895     0.969
# 2             2    0.772749    0.774  0.857     0.706      0.9     0.966
# 3             3    0.787132     0.75  0.857     0.667    0.885     0.952
# 4             4     0.76383    0.792  0.905     0.704    0.904     0.954
# mean                  0.779    0.768  0.871     0.687    0.895     0.958
# std                    0.01    0.017  0.031     0.018    0.008     0.009
#
#      #Features
# 0          124
# 1          124
# 2          124
# 3          124
# 4          124
# mean       124
# std          0

# %%
import matplotlib.pyplot as plt
def StackedHist(df):
    # Aggregate counts by Center and Morf_Codificata
    counts = df.groupby(['luogoTC_codificato', 'morf_codificata']).size().unstack(fill_value=0)

    # Define all possible center labels (1 to 14)
    all_centers = list(range(1, 15))
    all_labels = sorted(set(map(int,df['morf_codificata'])))
    
    # Reindex the DataFrame to include all centers, filling missing values with 0
    counts = counts.reindex(index=all_centers, columns=all_labels, fill_value=0)

    # Create the stacked histogram
    fig, ax = plt.subplots(figsize=(12, 10))

    # Initialize bottom positions for stacking
    bottom = np.zeros(len(all_centers))
    
    
    colors = plt.cm.tab20.colors



    # Plot each Morf_Codificata category as a stacked bar segment
    for i, label in enumerate(all_labels):
        ax.bar(all_centers, counts[label], bottom=bottom, label=f'{label}', color=colors[i])
        bottom += counts[label].values  # Update bottom for next stack

    # Set x-ticks from 1 to 14
    ax.set_xticks(all_centers)
    ax.set_xticklabels(all_centers, rotation=45, ha='right')

    # Adding labels and title
    plt.xlabel('Center')
    plt.ylabel('Count')
    plt.title('Stacked Histogram by Center and Morf_Codificata')
    plt.legend(title='Morf_Codificata', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
